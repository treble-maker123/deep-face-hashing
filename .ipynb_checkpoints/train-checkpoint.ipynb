# %%
import os
import uuid
import multiprocessing
from functools import reduce

import cv2

import numpy as np

import torch
import torchvision.transforms as T
from torch.utils.data import DataLoader, Dataset, sampler

from matplotlib import pyplot as plt

from pdb import set_trace

from ddh import *
from dataset import *
from logger import *

# %%
# reset the data

undo_create_set("val")
undo_create_set("test")
create_set("val")
create_set("test")

# %%
# switch to the appropriate device

if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %%
# add data transformation here

transform = T.Compose([
    T.ToPILImage(),
    T.Resize((32, 32)),
    T.ToTensor()
])

# %%
# build the dataset 

data_train = FaceScrubDataset(type="hash_label",
                              mode="train",
                              transform=transform)
data_val = FaceScrubDataset(type="hash_label",
                            mode="val",
                            transform=transform)
data_test = FaceScrubDataset(type="hash_label",
                             mode="test",
                             transform=transform)

# %%
# setting up the data loader

loader_params = {
    "shuffle": True,
    # "num_workers": multiprocessing.cpu_count() - 2
    "num_workers": 1
}

loader_train = DataLoader(data_train,
                          batch_size=256,
                          **loader_params)
loader_val = DataLoader(data_val,
                          batch_size=256,
                          **loader_params)
loader_test = DataLoader(data_test,
                          batch_size=256,
                          **loader_params)

# %%
# hyperparameters

num_epochs = 100

optimizer_params = {
    "lr": 1e-4,
    "weight_decay": 0.0
}
custom_params = {
    "beta": 1.0
}

# %%
# components
model = DiscriminativeDeepHashing()
model.to(device=device)
optimizer = optim.Adam(model.parameters(), **optimizer_params)

run_id = uuid.uuid4().hex.upper()[0:6]
checkpoint_path = os.getcwd() + "/models/{}_best_weights.pt".format(run_id)

# %%
# training code

with Logger(write_to_file=False) as logger:
    logger.write("Starting run for {}".format(run_id))

    for epoch in range(num_epochs):
        epoch_train_losses = []
        epoch_train_acc = []

        for num_iter, (X, y) in enumerate(loader_train):
            # set model to train mode
            model.train()
            # forward pass
            batch = X.to(device).float()
            batch_size = len(X)
            label = y.to(device).float()
            outputs = model(X)
            # calculating loss
            loss = F.binary_cross_entropy_with_logits(outputs, label)
            # loss to encourage code to be closer to -1 and 1
            loss += custom_params["beta"]* \
                        torch.abs((torch.abs(outputs)-1).sum()) / batch_size
            # back propagate
            optimizer.zero_grad()
            epoch_train_losses.append(loss.item())
            loss.backward()
            optimizer.step()
            # calculate accuracy over training data
            y = y.byte()
            output_hash = outputs.data > 0
            num_correct = ((output_hash == y).sum(1) == 0).sum().item()
            num_total = len(y)
            num_digits_correct = (output_hash == y).sum()
            num_digits_total = reduce(lambda x, y: x*y, output_hash.shape)

            print(
                "Epoch {} ".format(epoch) +
                "iter {}: ".format(num_iter) +
                "loss - {:.10f} ".format(loss.item()) +
                "correct/total - {}/{} ({}%)"
                    .format(num_correct, num_total,
                            num_correct * 100.0 / num_total) +
                "digits/total - {}/{} ({}%)"
                    .format(num_digits_correct, num_digits_total,
                            num_digits_correct * 100.0 / num_digits_total)
            )

    logger.write("Completed run for {}".format(run_id))
# Out:
# Starting run for FB8964
# Epoch 0 iter 0: loss - 43.5558433533 correct/total - 0/64 (0.0%)digits/total - 1570/3072 (51%)
# Epoch 1 iter 0: loss - 42.8694572449 correct/total - 0/64 (0.0%)digits/total - 1577/3072 (51%)
# Epoch 2 iter 0: loss - 42.1569099426 correct/total - 0/64 (0.0%)digits/total - 1571/3072 (51%)
# Epoch 3 iter 0: loss - 41.4229507446 correct/total - 0/64 (0.0%)digits/total - 1573/3072 (51%)
# Epoch 4 iter 0: loss - 40.6597213745 correct/total - 0/64 (0.0%)digits/total - 1581/3072 (51%)
# Epoch 5 iter 0: loss - 39.8700141907 correct/total - 0/64 (0.0%)digits/total - 1571/3072 (51%)
# Epoch 6 iter 0: loss - 39.0543556213 correct/total - 0/64 (0.0%)digits/total - 1575/3072 (51%)
# Epoch 7 iter 0: loss - 38.2154121399 correct/total - 0/64 (0.0%)digits/total - 1573/3072 (51%)
# Epoch 8 iter 0: loss - 37.3534164429 correct/total - 0/64 (0.0%)digits/total - 1563/3072 (50%)
# Epoch 9 iter 0: loss - 36.4646606445 correct/total - 0/64 (0.0%)digits/total - 1578/3072 (51%)
# Epoch 10 iter 0: loss - 35.5428199768 correct/total - 0/64 (0.0%)digits/total - 1587/3072 (51%)
# Epoch 11 iter 0: loss - 34.5945587158 correct/total - 0/64 (0.0%)digits/total - 1570/3072 (51%)
# Epoch 12 iter 0: loss - 33.6167068481 correct/total - 0/64 (0.0%)digits/total - 1569/3072 (51%)
# Epoch 13 iter 0: loss - 32.6102180481 correct/total - 0/64 (0.0%)digits/total - 1581/3072 (51%)
# Epoch 14 iter 0: loss - 31.5692348480 correct/total - 0/64 (0.0%)digits/total - 1570/3072 (51%)
# Epoch 15 iter 0: loss - 30.4918327332 correct/total - 0/64 (0.0%)digits/total - 1569/3072 (51%)
# Epoch 16 iter 0: loss - 29.3821563721 correct/total - 0/64 (0.0%)digits/total - 1573/3072 (51%)
# Epoch 17 iter 0: loss - 28.2356605530 correct/total - 0/64 (0.0%)digits/total - 1575/3072 (51%)
# Epoch 18 iter 0: loss - 27.0522804260 correct/total - 0/64 (0.0%)digits/total - 1576/3072 (51%)
# Epoch 19 iter 0: loss - 25.8260669708 correct/total - 0/64 (0.0%)digits/total - 1574/3072 (51%)
# Epoch 20 iter 0: loss - 24.5631122589 correct/total - 0/64 (0.0%)digits/total - 1586/3072 (51%)
# Epoch 21 iter 0: loss - 23.2591724396 correct/total - 0/64 (0.0%)digits/total - 1584/3072 (51%)
# Epoch 22 iter 0: loss - 21.9151420593 correct/total - 0/64 (0.0%)digits/total - 1568/3072 (51%)
# Epoch 23 iter 0: loss - 20.5291957855 correct/total - 0/64 (0.0%)digits/total - 1573/3072 (51%)
# Epoch 24 iter 0: loss - 19.1001110077 correct/total - 0/64 (0.0%)digits/total - 1572/3072 (51%)
# Epoch 25 iter 0: loss - 17.6224975586 correct/total - 0/64 (0.0%)digits/total - 1574/3072 (51%)
# Epoch 26 iter 0: loss - 16.1038761139 correct/total - 0/64 (0.0%)digits/total - 1579/3072 (51%)
# Epoch 27 iter 0: loss - 14.5394468307 correct/total - 0/64 (0.0%)digits/total - 1569/3072 (51%)
# Epoch 28 iter 0: loss - 12.9325418472 correct/total - 0/64 (0.0%)digits/total - 1575/3072 (51%)
# Epoch 29 iter 0: loss - 11.2753124237 correct/total - 0/64 (0.0%)digits/total - 1582/3072 (51%)
# Epoch 30 iter 0: loss - 9.5718908310 correct/total - 0/64 (0.0%)digits/total - 1572/3072 (51%)
# Epoch 31 iter 0: loss - 7.8216080666 correct/total - 0/64 (0.0%)digits/total - 1578/3072 (51%)
# Epoch 32 iter 0: loss - 6.0247974396 correct/total - 0/64 (0.0%)digits/total - 1589/3072 (51%)
# Epoch 33 iter 0: loss - 4.1830105782 correct/total - 0/64 (0.0%)digits/total - 1572/3072 (51%)
# Epoch 34 iter 0: loss - 2.2918391228 correct/total - 0/64 (0.0%)digits/total - 1582/3072 (51%)
# Epoch 35 iter 0: loss - 1.3220700026 correct/total - 0/64 (0.0%)digits/total - 1581/3072 (51%)
# Epoch 36 iter 0: loss - 2.8103652000 correct/total - 0/64 (0.0%)digits/total - 1576/3072 (51%)
# Epoch 37 iter 0: loss - 3.8740785122 correct/total - 0/64 (0.0%)digits/total - 1580/3072 (51%)
# Epoch 38 iter 0: loss - 4.5600152016 correct/total - 0/64 (0.0%)digits/total - 1580/3072 (51%)
# Epoch 39 iter 0: loss - 4.9178171158 correct/total - 0/64 (0.0%)digits/total - 1576/3072 (51%)
# Epoch 40 iter 0: loss - 4.9880876541 correct/total - 0/64 (0.0%)digits/total - 1582/3072 (51%)
# Epoch 41 iter 0: loss - 4.8078508377 correct/total - 0/64 (0.0%)digits/total - 1569/3072 (51%)
# Epoch 42 iter 0: loss - 4.4102573395 correct/total - 0/64 (0.0%)digits/total - 1581/3072 (51%)
# Epoch 43 iter 0: loss - 3.8302810192 correct/total - 0/64 (0.0%)digits/total - 1578/3072 (51%)
# Epoch 44 iter 0: loss - 3.0982964039 correct/total - 0/64 (0.0%)digits/total - 1577/3072 (51%)
# Epoch 45 iter 0: loss - 2.2267334461 correct/total - 0/64 (0.0%)digits/total - 1576/3072 (51%)
# Epoch 46 iter 0: loss - 1.2484014034 correct/total - 0/64 (0.0%)digits/total - 1573/3072 (51%)
# Epoch 47 iter 0: loss - 1.4890897274 correct/total - 0/64 (0.0%)digits/total - 1581/3072 (51%)
# Epoch 48 iter 0: loss - 2.2239322662 correct/total - 0/64 (0.0%)digits/total - 1581/3072 (51%)
# Epoch 49 iter 0: loss - 2.6842732430 correct/total - 0/64 (0.0%)digits/total - 1575/3072 (51%)
# Epoch 50 iter 0: loss - 2.9004476070 correct/total - 0/64 (0.0%)digits/total - 1575/3072 (51%)
# Epoch 51 iter 0: loss - 2.9031877518 correct/total - 0/64 (0.0%)digits/total - 1575/3072 (51%)
# Epoch 52 iter 0: loss - 2.7165510654 correct/total - 0/64 (0.0%)digits/total - 1577/3072 (51%)
# Epoch 53 iter 0: loss - 2.3670477867 correct/total - 0/64 (0.0%)digits/total - 1587/3072 (51%)
# Epoch 54 iter 0: loss - 1.8649287224 correct/total - 0/64 (0.0%)digits/total - 1571/3072 (51%)
# Epoch 55 iter 0: loss - 1.2268785238 correct/total - 0/64 (0.0%)digits/total - 1574/3072 (51%)
# Epoch 56 iter 0: loss - 1.2079644203 correct/total - 0/64 (0.0%)digits/total - 1573/3072 (51%)
# Epoch 57 iter 0: loss - 1.7062780857 correct/total - 0/64 (0.0%)digits/total - 1575/3072 (51%)
# Epoch 58 iter 0: loss - 1.9568796158 correct/total - 0/64 (0.0%)digits/total - 1577/3072 (51%)
# Epoch 59 iter 0: loss - 1.9920043945 correct/total - 0/64 (0.0%)digits/total - 1567/3072 (51%)
# Epoch 60 iter 0: loss - 1.8287085295 correct/total - 0/64 (0.0%)digits/total - 1579/3072 (51%)
# Epoch 61 iter 0: loss - 1.4960632324 correct/total - 0/64 (0.0%)digits/total - 1576/3072 (51%)
# Epoch 62 iter 0: loss - 1.0105506182 correct/total - 0/64 (0.0%)digits/total - 1581/3072 (51%)
# Epoch 63 iter 0: loss - 1.2756075859 correct/total - 0/64 (0.0%)digits/total - 1574/3072 (51%)
# Epoch 64 iter 0: loss - 1.6429383755 correct/total - 0/64 (0.0%)digits/total - 1576/3072 (51%)
# Epoch 65 iter 0: loss - 1.7941350937 correct/total - 0/64 (0.0%)digits/total - 1575/3072 (51%)
# Epoch 66 iter 0: loss - 1.7561669350 correct/total - 0/64 (0.0%)digits/total - 1573/3072 (51%)
# Epoch 67 iter 0: loss - 1.5451450348 correct/total - 0/64 (0.0%)digits/total - 1577/3072 (51%)
# Epoch 68 iter 0: loss - 1.1792869568 correct/total - 0/64 (0.0%)digits/total - 1581/3072 (51%)
# Epoch 69 iter 0: loss - 0.9995575547 correct/total - 0/64 (0.0%)digits/total - 1585/3072 (51%)
# Epoch 70 iter 0: loss - 1.2771478891 correct/total - 0/64 (0.0%)digits/total - 1575/3072 (51%)
# Epoch 71 iter 0: loss - 1.3447498083 correct/total - 0/64 (0.0%)digits/total - 1578/3072 (51%)
# Epoch 72 iter 0: loss - 1.2289650440 correct/total - 0/64 (0.0%)digits/total - 1578/3072 (51%)
# Epoch 73 iter 0: loss - 0.9419033527 correct/total - 0/64 (0.0%)digits/total - 1583/3072 (51%)
# Epoch 74 iter 0: loss - 1.1595280170 correct/total - 0/64 (0.0%)digits/total - 1569/3072 (51%)
# Epoch 75 iter 0: loss - 1.3730089664 correct/total - 0/64 (0.0%)digits/total - 1579/3072 (51%)
# Epoch 76 iter 0: loss - 1.3900682926 correct/total - 0/64 (0.0%)digits/total - 1571/3072 (51%)
# Epoch 77 iter 0: loss - 1.2327070236 correct/total - 0/64 (0.0%)digits/total - 1583/3072 (51%)
# Epoch 78 iter 0: loss - 0.9225942492 correct/total - 0/64 (0.0%)digits/total - 1585/3072 (51%)
# Epoch 79 iter 0: loss - 1.2077996731 correct/total - 0/64 (0.0%)digits/total - 1577/3072 (51%)
# Epoch 80 iter 0: loss - 1.4441218376 correct/total - 0/64 (0.0%)digits/total - 1571/3072 (51%)
# Epoch 81 iter 0: loss - 1.4752044678 correct/total - 0/64 (0.0%)digits/total - 1585/3072 (51%)
# Epoch 82 iter 0: loss - 1.3302048445 correct/total - 0/64 (0.0%)digits/total - 1584/3072 (51%)
# Epoch 83 iter 0: loss - 1.0221617222 correct/total - 0/64 (0.0%)digits/total - 1582/3072 (51%)
# Epoch 84 iter 0: loss - 1.0962044001 correct/total - 0/64 (0.0%)digits/total - 1570/3072 (51%)
# Epoch 85 iter 0: loss - 1.3242284060 correct/total - 0/64 (0.0%)digits/total - 1579/3072 (51%)
# Epoch 86 iter 0: loss - 1.3617494106 correct/total - 0/64 (0.0%)digits/total - 1585/3072 (51%)
# Epoch 87 iter 0: loss - 1.2270123959 correct/total - 0/64 (0.0%)digits/total - 1583/3072 (51%)
# Epoch 88 iter 0: loss - 0.9354799986 correct/total - 0/64 (0.0%)digits/total - 1578/3072 (51%)
# Epoch 89 iter 0: loss - 1.1718661785 correct/total - 0/64 (0.0%)digits/total - 1582/3072 (51%)
# Epoch 90 iter 0: loss - 1.3912043571 correct/total - 0/64 (0.0%)digits/total - 1578/3072 (51%)
# Epoch 91 iter 0: loss - 1.4117470980 correct/total - 0/64 (0.0%)digits/total - 1584/3072 (51%)
# Epoch 92 iter 0: loss - 1.2605714798 correct/total - 0/64 (0.0%)digits/total - 1580/3072 (51%)
# Epoch 93 iter 0: loss - 0.9489184618 correct/total - 0/64 (0.0%)digits/total - 1568/3072 (51%)
# Epoch 94 iter 0: loss - 1.1711614132 correct/total - 0/64 (0.0%)digits/total - 1565/3072 (50%)
# Epoch 95 iter 0: loss - 1.4025975466 correct/total - 0/64 (0.0%)digits/total - 1586/3072 (51%)
# Epoch 96 iter 0: loss - 1.4447345734 correct/total - 0/64 (0.0%)digits/total - 1580/3072 (51%)
# Epoch 97 iter 0: loss - 1.3200031519 correct/total - 0/64 (0.0%)digits/total - 1584/3072 (51%)
# Epoch 98 iter 0: loss - 1.0397131443 correct/total - 0/64 (0.0%)digits/total - 1581/3072 (51%)
# Epoch 99 iter 0: loss - 1.0556120872 correct/total - 0/64 (0.0%)digits/total - 1572/3072 (51%)
# Completed run for FB8964
